# %%
import os
import os.path
import json
import pandas as pd
import glob

# %%
# at colab we need to unzip
# !unzip dataset.zip -d .

# %%
# read and load a file
# . represents the relative path, change it to 'contents' in colab notebook: 'contents/dataset/
spam_sample = pd.read_json('dataset/SPAM/sample_01.json', typ='series')

# %%
print(spam_sample)
# Out:
# data    Hola, Torneos:\r\n\r\nExplorar más grupos\r\nh...
# dtype: object

# %%
# read and load a set of files
path_to_files = './dataset/NO_SPAM/'
json_pattern = os.path.join(path_to_files,'*.json')
file_list = glob.glob(json_pattern)

dfs = [] # an empty list to store the data frames

for file in file_list:
    data = pd.read_json(file, typ='series') # read data frame from json file
    dfs.append(data) # append the data frame to the list

no_spam = pd.concat(dfs, ignore_index=True) # concatenate all the data frames in the list.

# %%
no_spam.name

# %%
# exploring data
no_spam.describe()
# Out:
# count                                                    65
# unique                                                   65
# top       [image: Google]\r\nA new sign-in on Windows\r\...
# freq                                                      1
# dtype: object

# %%
# install nltk in colab notebook
# !pip install nltk

# %% [markdown]
# ## Exploring and cleaning our dataset

# %%
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem.wordnet import WordNetLemmatizer
import string, re
import nltk
nltk.download('omw-1.4')

def filter_words(raw_comments):
    """ Returns a filtered list
        Removes numbers and symbols from each comment
    """
    table = str.maketrans('', '', string.punctuation + string.digits)
    stripped = [comment.translate(table) for comment in raw_comments]
    return stripped

def lowercase_all(comments):
    """ Returns a list of lowercased words
    """
    return [comment.lower() for comment in comments]

def split_words(comments):
    """ Splits each comment as a list of strings, where each string is a word
    """
    return [re.split(r'\W+', comment) for comment in comments]

def flatten_words(comments):
    """ Returns a list of strings, where each string is a word
    """
    return [word for comment in comments for word in comment]

def remove_stopwords(words, language='english'):
    """ Returns a list filter out stop words
    """
    stop_words = set(stopwords.words(language))
    return [word for word in words if not word in stop_words]

def lemmatize(words):
    """ Lemma conversion
    """
    lem = WordNetLemmatizer()
    return [lem.lemmatize(word) for word in words]

def stemming(words):
    """ Linguistic normalization
    """
    ps = PorterStemmer()
    return [ps.stem(word) for word in words]
# Out:
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\ruben\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\omw-1.4.zip.

# %%
def create_vocabulary(data):
    """Pipeline to produce a word vocabulary

    Args:
        data (pandas dataframe): Dataframe containing your text data

    Returns:
        list: a word vocabulary
    """
    
    # strip reviews and place them in a single list
    raw_comments = list(data)

    # Create vocabulary
    filtered = filter_words(raw_comments)
    splitted = split_words(filtered)
    flattened = flatten_words(splitted)
    words = lowercase_all(flattened)
    words = remove_stopwords(words)
    words = lemmatize(words)
    words = stemming(words)
    return sorted(list(set(words)))

# %%
create_vocabulary(no_spam)
# Out:
# ['',
#  'aadrel',
#  'abandon',
#  'abil',
#  'abl',
#  'aboard',
#  'abou',
#  'abril',
#  'abrog',
#  'academ',
#  'academi',
#  'academia',
#  'academiaedu',
#  'accept',
#  'acceso',
#  'access',
#  'accordingli',
#  'account',
#  'accountcopi',
#  'aceptar',
#  'acerca',
#  'achiev',
#  'acid',
#  'across',
#  'action',
#  'activ',
#  'activar',
#  'actualizacion',
#  'actualización',
#  'acumul',
#  'ad',
#  'add',
#  'addit',
#  'address',
#  'addresshead',
#  'ademá',
#  'adfre',
#  'adjuntar',
#  'adjunto',
#  'adob',
#  'advantag',
#  'adventur',
#  'advic',
#  'advis',
#  'advisori',
#  'aeromexico',
#  'affect',
#  'affili',
#  'age',
#  'agenda',
#  'agendar',
#  'agent',
#  'agil',
#  'agre',
#  'agregado',
#  'agregar',
#  'agregu',
#  'ahora',
#  'ai',
#  'al',
#  'alan',
#  'album',
#  'alex',
#  'alguien',
#  'alguna',
#  'alguno',
#  'aliado',
#  'aligncent',
#  'alignleft',
#  'alignright',
#  'allaround',
#  'allow',
#  'alreadi',
#  'also',
#  'alt',
#  'alta',
#  'altandroid',
#  'altcustom',
#  'altemail',
#  'altfacebook',
#  'althttpssimagesiherbcomsnssnsmjpg',
#  'altiherb',
#  'altinstagram',
#  'altitun',
#  'altlabrada',
#  'altlif',
#  'altnatur',
#  'altpinterest',
#  'altruist',
#  'altst',
#  'altstar',
#  'altterri',
#  'alttwitt',
#  'altyoutub',
#  'alumnu',
#  'alvarez',
#  'alvarezjpg',
#  'alvhazelgmailcom',
#  'alvmtzgmailcom',
#  'alway',
#  'amaz',
#  'amazon',
#  'amazoncommx',
#  'ambit',
#  'america',
#  'ameyali',
#  'amir',
#  'amount',
#  'amphitheatr',
#  'analyt',
#  'analyz',
#  'andor',
#  'andrew',
#  'android',
#  'announc',
#  'answer',
#  'ant',
#  'anterior',
#  'anthoni',
#  'anticip',
#  'anular',
#  'anyon',
#  'anyth',
#  'anytim',
#  'anywher',
#  'aparecieron',
#  'apartar',
#  'apellidosmá',
#  'api',
#  'app',
#  'appear',
#  'appli',
#  'applic',
#  'approv',
#  'appsleft',
#  'appsright',
#  'april',
#  'aquí',
#  'arant',
#  'archivado',
#  'archivo',
#  'arcsiz',
#  'area',
#  'arent',
#  'arial',
#  'around',
#  'array',
#  'arriv',
#  'arrivalp',
#  'art',
#  'asegurarno',
#  'asegurars',
#  'asistent',
#  'ask',
#  'asociada',
#  'assess',
#  'assist',
#  'associ',
#  'assur',
#  'así',
#  'atención',
#  'atend',
#  'atentament',
#  'atkey',
#  'attach',
#  'audienc',
#  'austin',
#  'author',
#  'authorit',
#  'auto',
#  'autobord',
#  'autoimportantminwidthpxheightpxfontsizepxfontweightfontstylenormalfontstretchnormallineheightletterspacingnormalcolor',
#  'automaxwidthpx',
#  'automaxwidthpxbackgroundcolorfff',
#  'automaxwidthpxbackgroundcolorfffwidth',
#  'automaxwidthpxwidth',
#  'automaxwidthpxwidthbordercollapsecollaps',
#  'avail',
#  'ave',
#  'aviso',
#  'away',
#  'ayuda',
#  'azwbr',
#  'back',
#  'background',
#  'backgroundcolorfffbordercollapsecollaps',
#  'backgroundimag',
#  'backgroundimageurlhttpsegoelefemltrkcomvegoeleffduniquetwelcomeemail',
#  'backgroundimageurlhttpsegoelefemltrkcomvegoeleffduniquetwelcomeemailstylediv',
#  'backgroundimageurlhttpsegoelefemltrkcomvegoelefpduniquetwelcomeemail',
#  'backgroundpositioni',
#  'badg',
#  'banco',
#  'bandalo',
#  'barrow',
#  'base',
#  'battl',
#  'becom',
#  'begin',
#  'beginn',
#  'behind',
#  'believ',
#  'beneath',
#  'benefit',
#  'bern',
#  'best',
#  'better',
#  'beyond',
#  'bfeccb',
#  'bgcolorffffff',
#  'bienvenido',
#  'big',
#  'biggest',
#  'bill',
#  'billingpad',
#  'billion',
#  'bio',
#  'bird',
#  'bit',
#  'bittersweet',
#  'black',
#  'blockquot',
#  'blog',
#  'blueberri',
#  'blueprint',
#  'bluerich',
#  'blvd',
#  'bmp',
#  'bodi',
#  'bold',
#  'bolddat',
#  'bolder',
#  'boldercolor',
#  'boldlineheight',
#  'book',
#  'border',
#  'bordercollaps',
#  'borderradiuspxcolorfffdisplayinlineblockfontfamilysansseriffontsizepxfontweightboldlineheightpxtextaligncentertextdecorationnonewidthpxwebkittextsizeadjustnonemsohideal',
#  'borderradiuspxcolorfffdisplayinlineblockfontfamilysansseriffontsizepxfontweightboldlineheightpxtextaligncentertextdecorationnonewidthwebkittextsizeadjustnonemsohideal',
#  'borderspac',
#  'borrarlo',
#  'boston',
#  'bot',
#  'botcopi',
#  'boton',
#  'botsocieti',
#  'bottom',
#  'botón',
#  'br',
#  'brand',
#  'brbr',
#  'break',
#  'breakfast',
#  'bring',
#  'bro',
#  'broken',
#  'brought',
#  'browser',
#  'browserhttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypebrowserlinktempidijimjcwniid',
#  'browserhttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypebrowserlinktempidijimjcymcid',
#  'browserhttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypebrowserlinktempidijimtkxnyid',
#  'browserhttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypebrowserlinktempidijimtqyniid',
#  'browserhttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypebrowserlinktempidijiotizmcid',
#  'bruh',
#  'bruno',
#  'build',
#  'builder',
#  'built',
#  'bulk',
#  'buscando',
#  'busi',
#  'button',
#  'c',
#  'ca',
#  'cada',
#  'caducan',
#  'calc',
#  'calendar',
#  'california',
#  'call',
#  'cambiar',
#  'cambiará',
#  'cambio',
#  'camino',
#  'campo',
#  'cancel',
#  'cancelar',
#  'cannot',
#  'capsul',
#  'capsulesdiv',
#  'card',
#  'cardshttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkidjgnhsktempidijimjcwniidemailidchinocrgmailcomsidpkhhrlserverdefaulttypereplacedriptyp',
#  'cardshttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkidjgnhsktempidijimjcwniidemailidchinocrgmailcomsidtahhcserverdefaulttypereplacedriptyp',
#  'cardshttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkidjizkpftempidijimtkxnyidemailidchinocrgmailcomsidaeaqtlserverdefaulttypereplacedriptyp',
#  'cardshttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkidnkubdtempidijiotizmcidemailidchinocrgmailcomsidcelgserverdefaulttypereplacedriptyp',
#  'cardshttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkidnkubdtempidijiotizmcidemailidchinocrgmailcomsidxiyyserverdefaulttypereplacedriptyp',
#  'cardshttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkidwidotempidijimjcymcidemailidchinocrgmailcomsidwrotoserverdefaulttypereplacedriptyp',
#  'cardshttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkidwyltempidijimtqyniidemailidchinocrgmailcomsidbjvgyvserverdefaulttypereplacedriptyp',
#  'cardshttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkidwyltempidijimtqyniidemailidchinocrgmailcomsidgsoeeserverdefaulttypereplacedriptyp',
#  'care',
#  'carrier',
#  'case',
#  'caso',
#  'castro',
#  'catnolog',
#  'causa',
#  'ccccccborderradiuspxcolordisplayinlineblockfontfamilysansseriffontsizepxfontweightboldlineheightpxtextaligncentertextdecorationnonewidthwebkittextsizeadjustnonemsohideal',
#  'cdd',
#  'cdi',
#  'ce',
#  'celebr',
#  'cell',
#  'cellpad',
#  'cellspac',
#  'centenario',
#  'center',
#  'centro',
#  'centuri',
#  'ceo',
#  'certif',
#  'certifi',
#  'cest',
#  'challeng',
#  'chang',
#  'channel',
#  'charact',
#  'charisma',
#  'charsetutf',
#  'chatbot',
#  'check',
#  'checkup',
#  'cheer',
#  'cherri',
#  'child',
#  'chinocr',
#  'chinocrgmailcom',
#  'choos',
#  'christoph',
#  'cifrado',
#  'cinema',
#  'citi',
#  'ciudad',
#  'claim',
#  'clara',
#  'class',
#  'classbold',
#  'classboldd',
#  'classcolumn',
#  'classcont',
#  'classdeliveryt',
#  'classdeliverytext',
#  'classdivid',
#  'classfont',
#  'classfootertext',
#  'classhead',
#  'classheaderout',
#  'classiherblogo',
#  'classinn',
#  'classinnerproduct',
#  'classonecolumn',
#  'classorderdetail',
#  'classout',
#  'classpreheadertext',
#  'classproductscolumn',
#  'classproductstwocolumn',
#  'classresponsiveimag',
#  'classresponsivetextalign',
#  'classrightsidebar',
#  'classshippingtwocolumn',
#  'classshoptocolumn',
#  'classshowdesktop',
#  'classshowmobil',
#  'classsummarydetail',
#  'classtext',
#  'classtitl',
#  'classtitlecont',
#  'classtitleleft',
#  'classtopsellersmodul',
#  'classtwocolumn',
#  'classwebkit',
#  'classwrapp',
#  'clean',
#  'clear',
#  'clearer',
#  'clic',
#  'click',
#  'client',
#  'closer',
#  'code',
#  'cofound',
#  'cognigi',
#  'col',
#  'collaps',
#  'collapseborderradiu',
#  'collapseborderspac',
#  'collect',
#  'color',
#  'colspan',
#  'colspana',
#  'column',
#  'come',
#  'comentario',
#  'comment',
#  'commun',
#  'como',
#  'compani',
#  'compar',
#  'compat',
#  'complementari',
#  'complet',
#  'complimentari',
#  'comportamiento',
#  'compra',
#  'compraragendarapartar',
#  'comprimido',
#  'comprobar',
#  'comprueba',
#  'comput',
#  'con',
#  'concentr',
#  'concept',
#  'concern',
#  'condit',
#  'conditions¹',
#  'conduct',
#  'confer',
#  'configur',
#  'configuración',
#  'configuraron',
#  'confirm',
#  'congratul',
#  'connect',
#  'consid',
#  'consider',
#  'considerará',
#  'considéralo',
#  'consist',
#  'constant',
#  'constantli',
#  'constru',
#  'consulta',
#  'consum',
#  'contact',
#  'contacta',
#  'contactar',
#  'contacto',
#  'contain',
#  'containerid',
#  'content',
#  'contentieedg',
#  'contenttexthtml',
#  'contenturlhttpsegoelefemltrkcomvegoelefrdduniquetwelcomeemail',
#  'contenturlhttpsegoelefemltrkcomvegoelefrlduniquetwelcomeemail',
#  'contentwidthdevicewidthinitialscal',
#  'contestó',
#  'context',
#  'contien',
#  'contienen',
#  'continu',
#  'continuación',
#  'contract',
#  'contrario',
#  'contraseña',
#  'contribut',
#  'control',
#  'converg',
#  'convers',
#  'conversacion',
#  'convertir',
#  'convertirs',
#  'copi',
#  'copyright',
#  'coronaviru',
#  'corpor',
#  'correo',
#  'cosmosdb',
#  'cost',
#  'could',
#  'count',
#  'countri',
#  'coupontextright',
#  'cours',
#  'cover',
#  'covid',
#  'crea',
#  'creat',
#  'creativ',
#  'creator',
#  'credenti',
#  'credit',
#  'creek',
#  'crucial',
#  'ctextdecor',
#  'cto',
#  'cualquier',
#  'cuando',
#  'cubiertosxlsx',
#  'cuenta',
#  'current',
#  'custom',
#  'customerfac',
#  'cv',
#  'código',
#  'cómo',
#  'd',
#  'dado',
#  'damag',
#  'dar',
#  'dark',
#  'data',
#  'databaseid',
#  'dataignoreinlin',
#  'dataignoreinliningmedia',
#  'date',
#  'dato',
#  'day',
#  'dba',
#  'de',
#  'deal',
#  'dear',
#  'debe',
#  'deberá',
#  'debería',
#  'decid',
#  'decis',
#  'declaración',
#  'dedic',
#  'deep',
#  'deeper',
#  'defens',
#  'defin',
#  'dejará',
#  'del',
#  'delet',
#  'deliv',
#  'deliveri',
#  'deliveryt',
#  'deliverytext',
#  'deliverytitl',
#  'demo',
#  'depart',
#  'depict',
#  'deploy',
#  'derecha',
#  'derecho',
#  'desaparecido',
#  'desaparecieron',
#  'desd',
#  'desea',
#  'deshabilitación',
#  'design',
#  'detail',
#  'develop',
#  'devic',
#  'devop',
#  'diagnost',
#  'dialogflow',
#  'differ',
#  'digit',
#  'dilig',
#  'dimens',
#  'dimension',
#  'dinner',
#  'dirección',
#  'direct',
#  'directament',
#  'directli',
#  'directori',
#  'dirigirán',
#  'dirltr',
#  'dirrtl',
#  'disabl',
#  'disclaim',
#  'discontinu',
#  'discount',
#  'discov',
#  'discu',
#  'display',
#  'dispon',
#  'dispositivo',
#  'dissert',
#  'div',
#  'dive',
#  'divid',
#  'divif',
#  'divoutlookmessagehead',
#  'doc',
#  'doctor',
#  'doctyp',
#  'document',
#  'documento',
#  'docx',
#  'domicilio',
#  'done',
#  'dont',
#  'doubt',
#  'download',
#  'dress',
#  'drill',
#  'drive',
#  'driven',
#  'dublin',
#  'duda',
#  'duración',
#  'duti',
#  'dx',
#  'dynam',
#  'día',
#  'e',
#  'earli',
#  'earn',
#  'easi',
#  'easier',
#  'easili',
#  'ebook',
#  'ecm',
#  'ecmsp',
#  'edina',
#  'edit',
#  'educ',
#  'educativo',
#  'eeeborderradiu',
#  'effect',
#  'effort',
#  'ejemplo',
#  'ejercicio',
#  'el',
#  'electrónico',
#  'elig',
#  'elliot',
#  'els',
#  'em',
#  'email',
#  'emailfin',
#  'embarcadero',
#  'emielu',
#  'en',
#  'enabl',
#  'encontrará',
#  'encourag',
#  'end',
#  'endif',
#  'endifa',
#  'endors',
#  'endotheli',
#  'energi',
#  'engag',
#  'engin',
#  'enjoy',
#  'enlac',
#  'enriquecido',
#  'ensur',
#  'enter',
#  'enterpris',
#  'entertain',
#  'entrant',
#  'entrepreneur',
#  'enviado',
#  'enviar',
#  'environ',
#  'envió',
#  'envíano',
#  'envíen',
#  'envío',
#  'epic',
#  'equipo',
#  'eran',
#  'error',
#  'escrito',
#  'especialista',
#  'especificado',
#  'essay',
#  'essenti',
#  'est',
#  'esta',
#  'establish',
#  'estado',
#  'estim',
#  'estimado',
#  'está',
#  'esté',
#  'eszenyi',
#  'evalu',
#  'even',
#  'event',
#  'ever',
#  'everi',
#  'everyday',
#  'everyon',
#  'evolv',
#  'exactli',
#  'excel',
#  'except',
#  'excit',
#  'exclus',
#  'execut',
#  'exist',
#  'exit',
#  'expect',
#  'expens',
#  'experi',
#  'experienceso',
#  'expert',
#  'explicando',
#  'explor',
#  'export',
#  'express',
#  'extend',
#  'extens',
#  'extract',
#  'faborderradiuspxcolorffffffdisplayinlineblockfontfamilysansseriffontsizepxfontweightboldlineheightpxtextaligncentertextdecorationnonewidthpxwebkittextsizeadjustnonemsohideal',
#  'facebook',
#  'facil',
#  'fact',
#  'factor',
#  'fafafa',
#  'fafafaborderradiu',
#  'failur',
#  'falso',
#  'famili',
#  'familiar',
#  'fan',
#  'faq',
#  'far',
#  'fast',
#  'faster',
#  'favaro',
#  'favor',
#  'favorit',
#  'fawlljnfiznjwfflouvsalfsndjiopyvxcenmqhfuhwwjrmtotuneeblqksshaywpjmoyrsjoxq',
#  'featur',
#  'feb',
#  'februari',
#  'fecha',
#  'feed',
#  'feedback',
#  'feel',
#  'ferbecapit',
#  'fewer',
#  'fff',
#  'ffffontfamilylatohelveticaarialsansserift',
#  'file',
#  'fill',
#  'fillcolor',
#  'fillcolorfa',
#  'fillcolorffffff',
#  'final',
#  'finalizar',
#  'find',
#  'finish',
#  'finisimo',
#  'first',
#  'fit',
#  'flexibilidad',
#  'flexibl',
#  'flight',
#  'focu',
#  'follow',
#  'font',
#  'fontfamili',
#  'fontsiz',
#  'fontstretch',
#  'fontstyl',
#  'fontweight',
#  'foot',
#  'footeraddressrow',
#  'footercolumn',
#  'footericon',
#  'footert',
#  'forget',
#  'form',
#  'forma',
#  'format',
#  'formato',
#  'formulario',
#  'foro',
#  'forum',
#  'forward',
#  'four',
#  'francisco',
#  'frecuent',
#  'free',
#  'fri',
#  'friendli',
#  'frontera',
#  'full',
#  'fullday',
#  'fulli',
#  'fun',
#  'futur',
#  'futura',
#  'gadney',
#  'galeana',
#  'game',
#  'garcía',
#  'gartner',
#  'gather',
#  'generacion',
#  'generación',
#  'generó',
#  'genr',
#  'genérico',
#  'get',
#  'ghost',
#  'gif',
#  'gift',
#  'give',
#  'given',
#  'globe',
#  'gmt',
#  'go',
#  'goal',
#  'good',
#  'googl',
#  'gordon',
#  'got',
#  'gracia',
#  'gran',
#  'grant',
#  'grati',
#  'gratuito',
#  'gray',
#  'great',
#  'grightautofontsizepxlineheightcolor',
#  'ground',
#  'group',
#  'grow',
#  'gte',
#  'guarda',
#  'guardada',
#  'guayabo',
#  'guid',
#  'guphsup',
#  'guy',
#  'h',
#  'ha',
#  'haber',
#  'haberlo',
#  'hacer',
#  'haciendo',
#  'halo',
#  'han',
#  'happen',
#  'happi',
#  'harley',
#  'hará',
#  'harán',
#  'havent',
#  'haz',
#  'hazel',
#  'head',
#  'header',
#  'headerleft',
#  'headerout',
#  'headerright',
#  'headerruletop',
#  'health',
#  'healthi',
#  'height',
#  'hellog',
#  'help',
#  'helvetica',
#  'hemo',
#  'here',
#  'herehttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkiddlehxmtempidijimjcwniidemailidchinocrgmailcomsidpkhhrlserverdefaulttypereplacedriptyp',
#  'herehttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkiddlehxmtempidijimjcwniidemailidchinocrgmailcomsidtahhcserverdefaulttypereplacedriptyp',
#  'herehttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkidfgkdztempidijiotizmcidemailidchinocrgmailcomsidcelgserverdefaulttypereplacedriptyp',
#  'herehttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkidfgkdztempidijiotizmcidemailidchinocrgmailcomsidxiyyserverdefaulttypereplacedriptyp',
#  'herehttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkidnuzlbhtempidijimjcymcidemailidchinocrgmailcomsidwrotoserverdefaulttypereplacedriptyp',
#  'herehttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkidpgrkbtempidijimtkxnyidemailidchinocrgmailcomsidaeaqtlserverdefaulttypereplacedriptyp',
#  'herehttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkidynmiqttempidijimtqyniidemailidchinocrgmailcomsidbjvgyvserverdefaulttypereplacedriptyp',
#  'herehttpsptkbsfhtdexecuteapiuswestamazonawscomtrackcurrtracktypelinkclicklinkidynmiqttempidijimtqyniidemailidchinocrgmailcomsidgsoeeserverdefaulttypereplacedriptyp',
#  'herein',
#  'hermosillo',
#  'hermosillosonora',
#  'hey',
#  'hi',
#  'hidden',
#  'higher',
#  'highest',
#  'highli',
#  'highlight',
#  'highqual',
#  'hire',
#  'histori',
#  'hit',
#  'hmo',
#  'hola',
#  'holder',
#  'home',
#  'hook',
#  'hope',
#  'horario',
#  'hospit',
#  'host',
#  'hour',
#  'hous',
#  'howev',
#  'hr',
#  'hrefhttpiherbcomprpidutmsourcecommsutmmediumemailutmcampaignproductreviewutmcontentproductlink',
#  'hrefhttpsfontsgoogleapiscomcssfamilylato',
#  'hrefhttpsiherbcomsourcenaturalspomegranateextractmgtabletsutmsourcemessagecenterutmmediumemailutmcampaignpurchaseconfirmvutmcontentbodyproductlink',
#  'hrefhttpsitunesapplecomusappiherbid',
#  'hrefhttpsmxiherbcomhelpcontactutmsourcecommsutmmediumemailutmcampaignorderdeliveryutmcontentcontactusicon',
#  'hrefhttpsmxiherbcomhelpcontactutmsourcecommsutmmediumemailutmcampaignorderdeliveryutmcontentfootercontact',
#  'hrefhttpsmxiherbcomhelpcontactutmsourcecommsutmmediumemailutmcampaignproductreviewutmcontentcontactusicon',
#  'hrefhttpsmxiherbcomhelpcontactutmsourcecommsutmmediumemailutmcampaignproductreviewutmcontentfootercontact',
#  'hrefhttpsmxiherbcomhelpcontactutmsourcecommsutmmediumemailutmcampaignpurchaseconfirmvutmcontentfootercontact',
#  'hrefhttpsmxiherbcomhelpcontactutmsourcecommsutmmediumemailutmcampaignshippingconfirmvutmcontentcontactusicon',
#  'hrefhttpsmxiherbcomhelpcontactutmsourcecommsutmmediumemailutmcampaignshippingconfirmvutmcontentfootercontact',
#  'hrefhttpsmxiherbcomhelpcontactutmsourcecommsutmmediumemailutmcampaignwelcomeemailutmcontentcontactusicon',
#  'hrefhttpsmxiherbcomhelpcontactutmsourcecommsutmmediumemailutmcampaignwelcomeemailutmcontentfootercontact',
#  'hrefhttpsmxiherbcomhelpcontactutmsourcemessagecenterutmmediumemailutmcampaignpurchaseconfirmvutmcontentcontactusicon',
#  'hrefhttpsmxiherbcominfoprivacyutmsourcecommsutmmediumemailutmcampaignorderdeliveryutmcontentfooterprivaci',
#  'hrefhttpsmxiherbcominfoprivacyutmsourcecommsutmmediumemailutmcampaignproductreviewutmcontentfooterprivaci',
#  'hrefhttpsmxiherbcominfoprivacyutmsourcecommsutmmediumemailutmcampaignpurchaseconfirmvutmcontentfooterprivaci',
#  'hrefhttpsmxiherbcominfoprivacyutmsourcecommsutmmediumemailutmcampaignshippingconfirmvutmcontentfooterprivaci',
#  'hrefhttpsmxiherbcominfoprivacyutmsourcecommsutmmediumemailutmcampaignwelcomeemailutmcontentfooterprivaci',
#  'hrefhttpsmxiherbcomprlabradanutritionursolicacidleanmuscleoptimizercapsulesutmsourcecommsutmmediumemailutmcampaignshippingconfirmvutmcontentsimilarproductlinkstoreid',
#  'hrefhttpsmxiherbcomprlabradanutritionursolicacidleanmuscleoptimizercapsulesutmsourcemessagecenterutmmediumemailutmcampaignpurchaseconfirmvutmcontentsimilarproductlink',
#  'hrefhttpsmxiherbcomprlifeextensionendothelialdefensepomegranateplussoftgelsutmsourcemessagecenterutmmediumemailutmcampaignpurchaseconfirmvutmcontentsimilarproductlink',
#  'hrefhttpsmxiherbcomprlifeextensionpomegranatecompletesoftgelsutmsourcecommsutmmediumemailutmcampaignorderdeliveryutmcontentsimilarproductlinkstoreid',
#  'hrefhttpsmxiherbcomprlifeextensionpomegranatecompletesoftgelsutmsourcecommsutmmediumemailutmcampaignshippingconfirmvutmcontentsimilarproductlinkstoreid',
#  'hrefhttpsmxiherbcomprlifeextensionpomegranatecompletesoftgelsutmsourcemessagecenterutmmediumemailutmcampaignpurchaseconfirmvutmcontentsimilarproductlink',
#  'hrefhttpsmxiherbcomprnaturalfactorsbluerichsuperstrengthblueberryconcentratemgsoftgelsutmsourcecommsutmmediumemailutmcampaignshippingconfirmvutmcontentsimilarproductlinkstoreid',
#  'hrefhttpsmxiherbcomprstcenturypomegranatemgvegetariancapsulesutmsourcecommsutmmediumemailutmcampaignorderdeliveryutmcontentsimilarproductlinkstoreid',
#  'hrefhttpsmxiherbcomprterrynaturallypomegranateseedoilsoftgelsutmsourcecommsutmmediumemailutmcampaignorderdeliveryutmcontentsimilarproductlinkstoreid',
#  'hrefhttpsmxiherbcomugcmyaccountreviewutmsourcecommsutmmediumemailutmcampaignproductreviewutmcontentreviewearn',
#  'hrefhttpsplaygooglecomstoreappsdetailsidcomiherb',
#  'hrefhttpssecureiherbcomcommunicationspreferencesoptinstoreidshortcustomeridpzaerehbhobdpimrbqfolqorseoktyoznneunwdutmsourcecommsutmmediumemailutmcampaignorderdeliverycontentsignupv',
#  'hrefhttpssecureiherbcomcommunicationspreferencesoptinstoreidshortcustomeridpzaerehbhobdpimrbqfolqorseoktyoznneunwdutmsourcecommsutmmediumemailutmcampaignorderdeliveryutmcontentsignupv',
#  'hrefhttpssecureiherbcomcommunicationspreferencesoptinstoreidshortcustomeridpzaerehbhobdpimrbqfolqorseoktyoznneunwdutmsourcecommsutmmediumemailutmcampaignpurchaseconfirmvcontentsignupv',
#  'hrefhttpssecureiherbcomcommunicationspreferencesoptinstoreidshortcustomeridpzaerehbhobdpimrbqfolqorseoktyoznneunwdutmsourcecommsutmmediumemailutmcampaignshippingconfirmvcontentsignupv',
#  'hrefhttpssecureiherbcomcommunicationspreferencesoptinstoreidshortcustomeridpzaerehbhobdpimrbqfolqorseoktyoznneunwdutmsourcecommsutmmediumemailutmcampaignshippingconfirmvutmcontentsignupv',
#  'hrefhttpssecureiherbcomcommunicationspreferencesoptinutmsourcecommsutmmediumemailutmcampaignwelcomeemailutmcontentsignupshortcustomeridpzaerehbhobdpimrbqfolqorseoktyoznneunwdstoreid',
#  'hrefhttpssecureiherbcomcommunicationspreferencesoptinutmsourcecommsutmmediumemailutmcampaignwelcomeemailutmcontentsignupstoreidshortcustomeridpzaerehbhobdpimrbqfolqorseoktyoznneunwdstoreidsstoreid',
#  'hrefhttpssecureiherbcomcommunicationspreferencesutmsourcecommsutmmediumemailutmcampaignshippingconfirmvutmcontentsmsbutton',
#  'hrefhttpssecureiherbcommyaccountcommpreferencesutmsourcecommsutmmediumemailutmcampaignorderdeliveryutmcontentfooteremailprefer',
#  'hrefhttpssecureiherbcommyaccountcommpreferencesutmsourcecommsutmmediumemailutmcampaignproductreviewutmcontentfooteremailprefer',
#  'hrefhttpssecureiherbcommyaccountcommpreferencesutmsourcecommsutmmediumemailutmcampaignpurchaseconfirmvutmcontentfooteremailprefer',
#  'hrefhttpssecureiherbcommyaccountcommpreferencesutmsourcecommsutmmediumemailutmcampaignshippingconfirmvutmcontentfooteremailprefer',
#  'hrefhttpssecureiherbcommyaccountcommpreferencesutmsourcecommsutmmediumemailutmcampaignwelcomeemailutmcontentfooteremailprefer',
#  'hrefhttpssecureiherbcommyaccountmodifyorderonutmsourcemessagecenterutmmediumemailutmcampaignpurchaseconfirmvutmcontentcancelmodifi',
#  'hrefhttpssecureiherbcommyaccountoiutmsourcecommsutmmediumemailutmcampaignorderdeliveryutmcontentreturnher',
#  'hrefhttpssecureiherbcommyaccountordersummaryonutmsourcemessagecenterutmmediumemailutmcampaignpurchaseconfirmvutmcontentvieword',
#  'hrefhttpssecureiherbcomtrcarriertrackingordernumberamptrackingnumberecihbampcountrycodemxutmsourcecommsutmmediumemailutmcampaignorderdeliveryutmcontenttrackingnumberstoreid',
#  'hrefhttpssecureiherbcomtrcarriertrackingordernumberamptrackingnumberecihbampcountrycodemxutmsourcecommsutmmediumemailutmcampaignshippingconfirmvutmcontenttrackmypackagestoreid',
#  'hrefhttpssecureiherbcomtrreviewproductsrwewnvbohrdagvlxatwddproductidratingvalueutmsourcecommsutmmediumemailutmcampaignproductreviewutmcontentbodystarr',
#  'hrefhttpstwittercomiherb',
#  'hrefhttpswwwfacebookcomiherb',
#  'hrefhttpswwwinstagramcomiherb',
#  'hrefhttpswwwpinterestcomiherb',
#  'hrefhttpswwwyoutubecomciherb',
#  'hrefhttpwwwiherbcomprpidutmsourcecommsutmmediumemailutmcampaignproductreviewutmcontentbodyproductlink',
#  'hrefhttpwwwiherbcomprutmsourcecommsutmmediumemailutmcampaignorderdeliveryutmcontentshippeditemstoreid',
#  'hrefhttpwwwiherbcomutmsourcecommsutmmediumemailutmcampaignorderdeliveryutmcontentiherblogostoreid',
#  'hrefhttpwwwiherbcomutmsourcecommsutmmediumemailutmcampaignproductreviewutmcontentiherblogostoreid',
#  'hrefhttpwwwiherbcomutmsourcecommsutmmediumemailutmcampaignshippingconfirmvutmcontentiherblogostoreid',
#  'hrefhttpwwwiherbcomutmsourcecommsutmmediumemailutmcampaignwelcomeemailutmcontentiherblogostoreid',
#  'hrefhttpwwwiherbcomutmsourcemessagecenterutmmediumemailutmcampaignpurchaseconfirmvutmcontentiherblogostoreid',
#  'hrefmailtonoreplyinfoiherbcomnoreplyinfoiherbcoma',
#  'htm',
#  'html',
#  'httpequivcontenttyp',
#  'httpequivxuacompat',
#  'httphelpaccrediblecom',
#  '...',
#  '...',
#  'httpsacademiaedukeypassakrwdbqzdumtruadlqldfuuvmxnhpwwknwaznddhvcgjtyztlvnancbgcrznkcqstnealwzgcpqadfedbcddfbfeadfabfetdywtxqbykwpybuyqconfirmunsubscribecoursesupsel',
#  'httpsacademiaedukeypassmjjqmxrmxfmswwynqnwddrlltckovsttdemwsiwvthgrejtvttlxrsssowlhnjrrsnlzytkzwhwmcpqbcfffddfdfbbdctdywtxqcnymlzrpspconfirmunsubscribecoursesupsel',
#  'httpsaccountsgooglecomaccountchoosercontinuehttpstakeoutgooglecomsettingstakeoutdownloadjddadeccfceadidampemailchinocrgmailcom',
#  'httpsaccountsgooglecomaccountchoosercontinuehttpstakeoutgooglecomsettingstakeoutdownloadsampemailchinocrgmailcom',
#  'httpsaccountsgooglecomaccountchooseremailchinocrgmailcomcontinuehttpsmyaccountgooglecomalertntrfndrfncdeiddetd',
#  'httpsaccountsgooglecomaccountchooseremailchinocrgmailcomcontinuehttpsmyaccountgooglecomalertntrfndrfncdeiddetdanexpdnretfa',
#  'httpsaccountsgooglecomaccountchooseremailchinocrgmailcomcontinuehttpsmyaccountgooglecomsecuritycheckuputmsourcedgoogleutmmediumdemailutmcampaigndsapaneiddseadrfndanexpdnretfasapefasaprfsmconst',
#  'httpsaccountsgooglecomaccountchooseremailchinocrgmailcomcontinuehttpsphotosgooglecompartnerafqipogihmhfidkczwjkhixigwira',
#  'httpsapiaccrediblecomvauthinvitecodeeffcceaeecfcredentialidcfadabfbbdabedurlhttpsaffwwwcredentialnetfcfadabfbbdabedidentddbcfdfaddbd',
#  'httpsbotsocietyiodocumentationsunsettingbotsocietyutmsourcebotsocietyincutmcampaignabafaemailcampaigncopyutmmediumemailutmtermabeaabafa',
#  'httpsbotsocietyiodocumentationsunsettingbotsocietyutmsourcebotsocietyincutmcampaignabeacemailcampaigncopyutmmediumemailutmtermabeaabeac',
#  'httpsbotsocietyioutmsourcebotsocietyincutmcampaignabafaemailcampaigncopyutmmediumemailutmtermabeaabafa',
#  'httpsbotsocietyioutmsourcebotsocietyincutmcampaignabeacemailcampaigncopyutmmediumemailutmtermabeaabeac',
#  'httpsbotsocietyuslistmanagecomprofileuccbfbfaidabeaeaccabafa',
#  'httpsbotsocietyuslistmanagecomprofileuccbfbfaidabeaeaccabeac',
#  'httpsbotsocietyuslistmanagecomunsubscribeuccbfbfaidabeaeaccabafa',
#  'httpsbotsocietyuslistmanagecomunsubscribeuccbfbfaidabeaeaccabeac',
#  'httpscalendlycombotsocietyiomigrationofficehoursutmsourcebotsocietyincutmcampaignabafaemailcampaigncopyutmmediumemailutmtermabeaabafa',
#  'httpscalendlycombotsocietyiomigrationofficehoursutmsourcebotsocietyincutmcampaignabeacemailcampaigncopyutmmediumemailutmtermabeaabeac',
#  'httpscatnologydbdocumentsazurecom',
#  'httpschemaorg',
#  '',
#  '...',
#  '...',
#  '',
#  'httpsdocsgooglecomdocumentdjfjzpxxylispxowgsgdpyapheifzdrrsedituspsharingtseb',
#  'httpsdocsgooglecomspreadsheetsdhhisxvjfprapcbtefkoqktwyhedituspsharingrtpoftruesdtruet',
#  'httpsdocsgooglecomspreadsheetsdvlqsmpvsrrhfaoghrorwatwdbbpysynmiihhqixuedituspsharingt',
#  'httpsdrivegooglecomdrivefolderslugfznygvcslqgjxstrvzjyjqhuspsharingtscd',
#  '',
#  'httpseplpaypalcommunicationcomhvadbcafbbebfefddaccaaebdefdhtml',
#  'httpseplpaypalcommunicationcomhvecbfbacffbbccbcafehtml',
#  ...]
